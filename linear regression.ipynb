# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
data=pd.read_csv(r"C:\Users\bathma\Downloads\machine learning\hotel.csv")

# %%
X=data['Price in Millions']
Y=data['Square Meter']
plt.scatter(X,Y)

# %%
Y=2*X-4+data['Square Meter']
plt.scatter(X,Y)

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression(fit_intercept=True)
model.fit(X[:,np.newaxis],Y)
Xfit=np.linspace(0,35,1000)
Yfit=model.predict(Xfit[:,np.newaxis])
plt.scatter(X,Y)
# Out:
# <ipython-input-52-1da1c343e222>:3: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   model.fit(X[:,np.newaxis],Y)

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression(fit_intercept=True)
model.fit(X[:,np.newaxis],Y)
Xfit=np.linspace(0,35,1000)
Yfit=model.predict(Xfit[:,np.newaxis])
plt.scatter(Xfit,Yfit)
# Out:
# <ipython-input-53-2c86b85e190c>:3: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   model.fit(X[:,np.newaxis],Y)

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression(fit_intercept=True)
model.fit(X[:,np.newaxis],Y)
Xfit=np.linspace(0,35,1000)
Yfit=model.predict(Xfit[:,np.newaxis])
plt.scatter(X,Y)
plt.scatter(Xfit,Yfit)
# Out:
# <ipython-input-54-48966c21acb0>:3: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   model.fit(X[:,np.newaxis],Y)

# %%
model.coef_[0]
# Out:
# 121.20279630775725

# %%
model.intercept_
# Out:
# 354.6950577311559
